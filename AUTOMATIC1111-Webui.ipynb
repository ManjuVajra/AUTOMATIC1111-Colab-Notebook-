# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 16434, done.
# remote: Total 16434 (delta 0), reused 0 (delta 0), pack-reused 16434
# Receiving objects: 100% (16434/16434), 27.51 MiB | 17.84 MiB/s, done.
# Resolving deltas: 100% (11493/11493), done.

# %%
# %cd stable-diffusion-webui
# Out:
# /content/stable-diffusion-webui

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting blendmodes
#   Downloading blendmodes-2022-py3-none-any.whl (10 kB)
# Collecting accelerate
#   Downloading accelerate-0.16.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 18.5 MB/s eta 0:00:00
# Collecting basicsr
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 KB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fonts
#   Downloading fonts-0.0.3-py3-none-any.whl (4.2 kB)
# Collecting font-roboto
#   Downloading font-roboto-0.0.1.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 94.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gfpgan
#   Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 KB 5.9 MB/s eta 0:00:00
# Collecting gradio==3.16.2
#   Downloading gradio-3.16.2-py3-none-any.whl (14.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 95.5 MB/s eta 0:00:00
# Collecting invisible-watermark
#   Downloading invisible_watermark-0.1.5-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (1.22.4)
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (4.6.0.66)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (2.25.1)
# Collecting piexif
#   Downloading piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (8.4.0)
# Collecting pytorch_lightning==1.7.7
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 KB 62.2 MB/s eta 0:00:00
# Collecting realesrgan
#   Downloading realesrgan-0.3.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: scikit-image>=0.19 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 17)) (0.19.3)
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 36.3 MB/s eta 0:00:00
# Collecting transformers==4.25.1
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 111.3 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 20)) (1.13.1+cu116)
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 5.8 MB/s eta 0:00:00
# Collecting jsonmerge
#   Downloading jsonmerge-1.9.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting clean-fid
#   Downloading clean_fid-0.1.35-py3-none-any.whl (26 kB)
# Collecting resize-right
#   Downloading resize_right-0.0.2-py3-none-any.whl (8.9 kB)
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Collecting kornia
#   Downloading kornia-0.6.10-py2.py3-none-any.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.0/612.0 KB 38.8 MB/s eta 0:00:00
# Collecting lark
#   Downloading lark-1.1.5-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 KB 12.6 MB/s eta 0:00:00
# Collecting inflection
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting GitPython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 21.4 MB/s eta 0:00:00
# Collecting torchsde
#   Downloading torchsde-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 6.8 MB/s eta 0:00:00
# Collecting safetensors
#   Downloading safetensors-0.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 32)) (5.4.8)
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 7.5 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.7-cp39-cp39-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 KB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (6.0)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 6.3 MB/s eta 0:00:00
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 2.3 MB/s eta 0:00:00
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 10.4 MB/s eta 0:00:00
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome
#   Downloading pycryptodome-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.8 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (3.5.3)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (4.5.0)
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (1.10.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (2023.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (1.3.5)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.3 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (4.2.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (3.1.2)
# Collecting fastapi
#   Downloading fastapi-0.93.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 8.2 MB/s eta 0:00:00
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (4.65.0)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.3-py3-none-any.whl (518 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.6/518.6 KB 55.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (23.0)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.11.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from timm==0.4.12->-r requirements.txt (line 18)) (0.14.1+cu116)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (3.9.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 93.8 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.13.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 KB 1.5 MB/s eta 0:00:00
# Collecting aenum<4,>=3.1.7
#   Downloading aenum-3.1.11-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 KB 18.5 MB/s eta 0:00:00
# Collecting Pillow
#   Downloading Pillow-9.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 85.1 MB/s eta 0:00:00
# Collecting deprecation<3,>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (0.16.0)
# Collecting lmdb
#   Downloading lmdb-1.4.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.9/305.9 KB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (4.6.0.66)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (1.10.1)
# Collecting tb-nightly
#   Downloading tb_nightly-2.13.0a20230308-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 68.5 MB/s eta 0:00:00
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 22.3 MB/s eta 0:00:00
# Collecting facexlib>=0.2.5
#   Downloading facexlib-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 KB 7.9 MB/s eta 0:00:00
# Collecting onnxruntime
#   Downloading onnxruntime-1.14.1-cp39-cp39-manylinux_2_27_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 114.1 MB/s eta 0:00:00
# Collecting onnx
#   Downloading onnx-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 109.1 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from invisible-watermark->-r requirements.txt (line 8)) (1.4.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (4.0.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (2023.2.28)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (2.9.0)
# Requirement already satisfied: jsonschema>2.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonmerge->-r requirements.txt (line 22)) (4.3.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.8 MB/s eta 0:00:00
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Collecting boltons>=20.2.1
#   Downloading boltons-23.0.0-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.16.2->-r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.16.2->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from facexlib>=0.2.5->gfpgan->-r requirements.txt (line 6)) (0.56.4)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 KB 24.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (22.2.0)
# Collecting charset-normalizer<4.0,>=2.0
#   Downloading charset_normalizer-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 23.9 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.6 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 15.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>2.4.0->jsonmerge->-r requirements.txt (line 22)) (0.19.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.16.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.16.2->-r requirements.txt (line 7)) (2022.7.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.19.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.4.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.51.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.16.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (57.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.8.1)
# Collecting starlette<0.26.0,>=0.25.0
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 8.5 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 8.1 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.5-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 6.0 MB/s eta 0:00:00
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (4.39.0)
# Collecting protobuf<4,>=3.9.2
#   Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.9/dist-packages (from onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (23.3.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (1.7.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 5.8 MB/s eta 0:00:00
# Collecting tb-nightly
#   Downloading tb_nightly-2.13.0a20230307-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 111.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230306-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 116.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230305-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 104.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230304-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 116.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230303-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 119.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230302-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 125.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230301-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 114.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230228-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 118.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230226-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 119.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230225-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 123.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230224-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 121.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230223-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 114.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230221-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 11.9 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230220-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 118.8 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230219-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 117.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230218-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 116.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230217-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 105.9 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230215-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 94.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230214-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 110.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230213-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 116.9 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230212-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 100.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230211-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 116.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230210-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 119.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230209-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 119.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230207-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 121.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230206-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 119.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230205-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 115.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230204-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 105.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230203-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 116.9 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230202-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 114.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230201-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 121.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230131-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 100.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230130-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 10.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230129-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 111.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230128-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 120.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230127-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 109.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230126-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 118.5 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio==3.16.2->-r requirements.txt (line 7)) (8.1.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.3.1)
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 10.7 MB/s eta 0:00:00
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (6.0.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->facexlib>=0.2.5->gfpgan->-r requirements.txt (line 6)) (0.39.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.2.2)
# Building wheels for collected packages: basicsr, font-roboto, antlr4-python3-runtime, jsonmerge, ffmpy, filterpy
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214840 sha256=1d145d8cefd10903aa25c6276ed512da3ff0b82ec11cc2334a47b43916a2ea02
#   Stored in directory: /root/.cache/pip/wheels/42/d6/3d/6d8c4b8fabeb93dd442eb255f133e8928c75d903fe20e9472c
#   Building wheel for font-roboto (setup.py) ... done
#   Created wheel for font-roboto: filename=font_roboto-0.0.1-py3-none-any.whl size=2359754 sha256=40cbe247204f952457a7996f7f3eb0071678400b1eff905548dfb501353f99cc
#   Stored in directory: /root/.cache/pip/wheels/26/36/01/d5840af8f7419a9361142426ff7709b529f8e3624ae2248c68
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=d58e382a51552f3e5273bb33fc8b4acc584c8e491247d37f567720996b257784
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for jsonmerge (setup.py) ... done
#   Created wheel for jsonmerge: filename=jsonmerge-1.9.0-py3-none-any.whl size=18633 sha256=4ee948c5b1adf2946d138343870f6fbf1c104cba4fba9f3931344c52b1713687
#   Stored in directory: /root/.cache/pip/wheels/09/0f/dd/bd5a8b81ed1feef7d08fea857f7bee591e481a484e6bee317a
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4711 sha256=f09585cfe94fe62e1d415870fc1aa59ca670025093ebb081cbf68b94d64d7694
#   Stored in directory: /root/.cache/pip/wheels/91/e2/96/f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110474 sha256=22f6a83c26b2486dcb3a0e507330cc7c0f9a44db0f066677ec559479476a04c0
#   Stored in directory: /root/.cache/pip/wheels/53/e6/de/a09ea01e923aaf88b9f8c7c44329e857b2c1a31901167e55e6
# Successfully built basicsr font-roboto antlr4-python3-runtime jsonmerge ffmpy filterpy
# Installing collected packages: yapf, trampoline, tokenizers, safetensors, rfc3986, resize-right, pydub, lmdb, lark, fonts, font-roboto, ffmpy, boltons, antlr4-python3-runtime, aenum, addict, websockets, uc-micro-py, sniffio, smmap, python-multipart, pyDeprecate, pycryptodome, protobuf, Pillow, piexif, orjson, omegaconf, multidict, mdurl, inflection, humanfriendly, h11, frozenlist, einops, deprecation, charset-normalizer, async-timeout, aiofiles, yarl, uvicorn, torchsde, torchmetrics, torchdiffeq, onnx, markdown-it-py, linkify-it-py, kornia, jsonmerge, huggingface-hub, gitdb, coloredlogs, blendmodes, anyio, aiosignal, accelerate, transformers, timm, starlette, onnxruntime, mdit-py-plugins, httpcore, GitPython, filterpy, clean-fid, aiohttp, tb-nightly, invisible-watermark, httpx, fastapi, facexlib, pytorch_lightning, gradio, basicsr, gfpgan, realesrgan
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed GitPython-3.1.31 Pillow-9.4.0 accelerate-0.16.0 addict-2.4.0 aenum-3.1.11 aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 anyio-3.6.2 async-timeout-4.0.2 basicsr-1.4.2 blendmodes-2022 boltons-23.0.0 charset-normalizer-3.1.0 clean-fid-0.1.35 coloredlogs-15.0.1 deprecation-2.1.0 einops-0.6.0 facexlib-0.2.5 fastapi-0.93.0 ffmpy-0.3.0 filterpy-1.4.5 font-roboto-0.0.1 fonts-0.0.3 frozenlist-1.3.3 gfpgan-1.3.8 gitdb-4.0.10 gradio-3.16.2 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 huggingface-hub-0.13.0 humanfriendly-10.0 inflection-0.5.1 invisible-watermark-0.1.5 jsonmerge-1.9.0 kornia-0.6.10 lark-1.1.5 linkify-it-py-2.0.0 lmdb-1.4.0 markdown-it-py-2.2.0 mdit-py-plugins-0.3.5 mdurl-0.1.2 multidict-6.0.4 omegaconf-2.3.0 onnx-1.13.1 onnxruntime-1.14.1 orjson-3.8.7 piexif-1.1.3 protobuf-3.20.3 pyDeprecate-0.3.2 pycryptodome-3.17 pydub-0.25.1 python-multipart-0.0.6 pytorch_lightning-1.7.7 realesrgan-0.3.0 resize-right-0.0.2 rfc3986-1.5.0 safetensors-0.3.0 smmap-5.0.0 sniffio-1.3.0 starlette-0.25.0 tb-nightly-2.12.0a20230126 timm-0.4.12 tokenizers-0.13.2 torchdiffeq-0.2.3 torchmetrics-0.11.3 torchsde-0.2.5 trampoline-0.1.2 transformers-4.25.1 uc-micro-py-1.0.1 uvicorn-0.20.0 websockets-10.4 yapf-0.32.0 yarl-1.8.2

# %%
# !python launch.py --share --xformers
# Out:
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: 0cc0ee1bcb4c24a8c9715f66cede06601bfc00c8
# Installing clip
# Installing open_clip
# Installing xformers
# Cloning Stable Diffusion into repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --xformers
# 2023-03-08 23:26:59.256160: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-08 23:27:00.640452: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-08 23:27:00.640587: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-08 23:27:00.640621: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Downloading: "https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors" to /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.safetensors
#
# 100% 3.97G/3.97G [00:27<00:00, 155MB/s]
# Calculating sha256 for /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.safetensors: 6ce0161689b3853acaa03779ec93eafe75a02f4ced659bee03f50797806fa2fa
# Loading weights [6ce0161689] from /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.safetensors
# Creating model from config: /content/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:01<00:00, 858kB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 588kB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 124kB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 343kB/s]
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 642kB/s]
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(0):
# Model loaded in 39.1s (calculate hash: 12.5s, create model: 12.3s, apply weights to model: 5.1s, apply half(): 1.3s, load VAE: 7.1s, move model to device: 0.6s).
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://f9f9ad0e-c344-4339.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:06<02:12,  6.95s/it]
#  15% 3/20 [00:07<00:28,  1.67s/it]
#  20% 4/20 [00:07<00:17,  1.07s/it]
#  25% 5/20 [00:07<00:11,  1.35it/s]
#  30% 6/20 [00:07<00:07,  1.84it/s]
#  35% 7/20 [00:07<00:05,  2.39it/s]
#  40% 8/20 [00:08<00:04,  2.98it/s]
#  45% 9/20 [00:08<00:03,  3.59it/s]
#  50% 10/20 [00:08<00:02,  4.16it/s]
#  55% 11/20 [00:08<00:01,  4.66it/s]
#  60% 12/20 [00:08<00:01,  5.10it/s]
#  65% 13/20 [00:08<00:01,  5.31it/s]
#  70% 14/20 [00:09<00:01,  5.38it/s]
#  75% 15/20 [00:09<00:00,  5.31it/s]
#  80% 16/20 [00:09<00:00,  5.35it/s]
#  85% 17/20 [00:09<00:00,  5.50it/s]
#  90% 18/20 [00:09<00:00,  5.50it/s]
#  95% 19/20 [00:09<00:00,  5.76it/s]
# 100% 20/20 [00:10<00:00,  1.99it/s]
# Total progress: 100% 20/20 [00:07<00:00,  2.55it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:04,  4.20it/s]
#  15% 3/20 [00:00<00:02,  5.77it/s]
#  20% 4/20 [00:00<00:02,  6.00it/s]
#  25% 5/20 [00:00<00:02,  6.14it/s]
#  30% 6/20 [00:01<00:02,  6.24it/s]
#  35% 7/20 [00:01<00:02,  6.32it/s]
#  40% 8/20 [00:01<00:01,  6.30it/s]
#  45% 9/20 [00:01<00:01,  6.32it/s]
#  50% 10/20 [00:01<00:01,  6.35it/s]
#  55% 11/20 [00:01<00:01,  6.39it/s]
#  60% 12/20 [00:01<00:01,  6.38it/s]
#  65% 13/20 [00:02<00:01,  6.36it/s]
#  70% 14/20 [00:02<00:00,  6.38it/s]
#  75% 15/20 [00:02<00:00,  6.37it/s]
#  80% 16/20 [00:02<00:00,  6.35it/s]
#  85% 17/20 [00:02<00:00,  6.34it/s]
#  90% 18/20 [00:02<00:00,  6.36it/s]
#  95% 19/20 [00:03<00:00,  6.33it/s]
# 100% 20/20 [00:03<00:00,  6.22it/s]
# Total progress: 100% 20/20 [00:03<00:00,  6.07it/s]
# Interrupted with signal 2 in <frame at 0xeb231b0, file '/content/stable-diffusion-webui/webui.py', line 173, code wait_on_server>
